# %% [markdown]
# <a href="https://colab.research.google.com/github/Harish-b19/python/blob/main/py_class4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
bank = [
    [
        [
            ["C101", "Rahul", "Savings", 85000],
            ["C102", "Anita", "Current", 150000],
            ["C103", "Kiran", "Loan", 500000]
        ],
        [
            ["C104", "Sneha", "Savings", 95000],
            ["C105", "Vikram", "Current", 275000],
            ["C106", "Meena", "Loan", 750000]
        ]
    ],

    [
        [
            ["C201", "Arjun", "Savings", 120000],
            ["C202", "Pooja", "Current", 325000],
            ["C203", "Ramesh", "Loan", 900000]
        ],
        [
            ["C204", "Priya", "Savings", 45000],
            ["C205", "Amit", "Current", 185000],
            ["C206", "Divya", "Loan", 650000]
        ]
    ],

    [
        [
            ["C301", "Nikhil", "Savings", 78000],
            ["C302", "Kavya", "Current", 240000],
            ["C303", "Suresh", "Loan", 1000000]
        ],
        [
            ["C304", "Neha", "Savings", 135000],
            ["C305", "Rohan", "Current", 410000],
            ["C306", "Asha", "Loan", 550000]
        ]
    ]
]

# %% [markdown]
# 1. Print Rahul's complete record.
#
# 2. Print Anita's account type.
#
# 3. Print Kiran's loan amount.
#
# 4. Print Sneha's customer ID.
#
# 5. Print Vikram's balance.
#
# 6. Print Meena's complete record.
#
# 7. Print Arjun's customer ID.
#
# 8. Print Pooja's name.
#
# 9. Print Ramesh's account type.
#
# 10. Print Priya's balance.
#
# 11. Print Amit's account type.
#
# 12. Print Divya's customer ID.
#
# 13. Print Nikhil's account type.
#
# 14. Print Kavya's balance.
#
# 15. Print Suresh's loan amount.
#
# 16. Print Neha's name.
#
# 17. Print Rohan's complete record.
#
# 18. Print Asha's account type.
#
# 19. Print all customers in Bank 1, Branch 1.
#
# 20. Print all customers in Bank 1, Branch 2.
#
# 21. Print all customers in Bank 2, Branch 1.
#
# 22. Print all customers in Bank 2, Branch 2.
#
# 23. Print all customers in Bank 3, Branch 1.
#
# 24. Print all customers in Bank 3, Branch 2.
#
# 25. Print all branches of Bank 1.
#
# 26. Print all branches of Bank 2.
#
# 27. Print all branches of Bank 3.
#
# 28. Print the first customer from every bank's first branch.
#
# 29. Print the second customer from every bank's second branch.
#
# 30. Print the loan amount of the last customer in Bank 3, Branch 2.

# %%
print("rahul record:",bank[0][0][0])
# Out:
# rahul record: ['C101', 'Rahul', 'Savings', 85000]

# %%
print("anitha account type:",bank[0][0][1][2])
# Out:
# anitha account type: Current

# %%
print("kiran loan amount: ",bank[0][0][2][3])
# Out:
# kiran loan amount:  500000

# %%
print("sneha ID:",bank[0][1][0][0])
# Out:
# sneha ID: C104

# %%
print("vikaram balance:",bank[0][1][1][3])
# Out:
# vikaram balance: 275000

# %%
print("meena record:",bank[0][1][2])
# Out:
# meena record: ['C106', 'Meena', 'Loan', 750000]

# %%
print("arjun id:",bank[1][0][0][0])
# Out:
# arjun id: C201

# %%
print("pooja name:",bank[1][0][1][1])
# Out:
# pooja name: Pooja

# %%
print("ramesh account type:",bank[1][0][2][2])
# Out:
# ramesh account type: Loan

# %%
print("priya balance:",bank[1][1][0][3])
# Out:
# priya balance: 45000

# %%
print("amith account type:",bank[1][1][1][2])
# Out:
# amith account type: Current

# %%
print("divya id:",bank[1][1][2][0])
# Out:
# divya id: C206

# %%
print("nikhil account type:",bank[2][0][0][0])
# Out:
# nikhil account type: C301

# %%
print("kavya balance:",bank[2][0][1][3])
# Out:
# kavya balance: 240000

# %%
print("suresh loan:",bank[2][0][2][3])
# Out:
# suresh loan: 1000000

# %%
print("neha name:",bank[2][1][0][1])
# Out:
# neha name: Neha

# %%
print("rohan record:",bank[2][1][1])
# Out:
# rohan record: ['C305', 'Rohan', 'Current', 410000]

# %%
print("asha account:",bank[2][1][2][2])
# Out:
# asha account: Loan

# %%
print("bank 1 ,branch 1:",bank[0][0])
# Out:
# bank 1 ,branch 1: [['C101', 'Rahul', 'Savings', 85000], ['C102', 'Anita', 'Current', 150000], ['C103', 'Kiran', 'Loan', 500000]]

# %%
print("bank 1,branch 2:",bank[0][1])
# Out:
# bank 1,branch 2: [['C104', 'Sneha', 'Savings', 95000], ['C105', 'Vikram', 'Current', 275000], ['C106', 'Meena', 'Loan', 750000]]

# %%
print("bank 2,branch 1:",bank[1][0])
# Out:
# bank 2,branch 1: [['C201', 'Arjun', 'Savings', 120000], ['C202', 'Pooja', 'Current', 325000], ['C203', 'Ramesh', 'Loan', 900000]]

# %%
print("bank 2,branch 2:",bank[1][1])
# Out:
# bank 2,branch 2: [['C204', 'Priya', 'Savings', 45000], ['C205', 'Amit', 'Current', 185000], ['C206', 'Divya', 'Loan', 650000]]

# %%
print("bank 3,branch 1:",bank[2][0])
# Out:
# bank 3,branch 1: [['C301', 'Nikhil', 'Savings', 78000], ['C302', 'Kavya', 'Current', 240000], ['C303', 'Suresh', 'Loan', 1000000]]

# %%
print("bank 3,branch 2:",bank[2][1])
# Out:
# bank 3,branch 2: [['C304', 'Neha', 'Savings', 135000], ['C305', 'Rohan', 'Current', 410000], ['C306', 'Asha', 'Loan', 550000]]

# %%
print(" bank 1:",bank[0])
# Out:
#  bank 1: [[['C101', 'Rahul', 'Savings', 85000], ['C102', 'Anita', 'Current', 150000], ['C103', 'Kiran', 'Loan', 500000]], [['C104', 'Sneha', 'Savings', 95000], ['C105', 'Vikram', 'Current', 275000], ['C106', 'Meena', 'Loan', 750000]]]

# %%
print("bank 2:",bank[1])
# Out:
# bank 2: [[['C201', 'Arjun', 'Savings', 120000], ['C202', 'Pooja', 'Current', 325000], ['C203', 'Ramesh', 'Loan', 900000]], [['C204', 'Priya', 'Savings', 45000], ['C205', 'Amit', 'Current', 185000], ['C206', 'Divya', 'Loan', 650000]]]

# %%
print("bank 3:",bank[2])
# Out:
# bank 3: [[['C301', 'Nikhil', 'Savings', 78000], ['C302', 'Kavya', 'Current', 240000], ['C303', 'Suresh', 'Loan', 1000000]], [['C304', 'Neha', 'Savings', 135000], ['C305', 'Rohan', 'Current', 410000], ['C306', 'Asha', 'Loan', 550000]]]

# %%
print("first_customer of first branch:",bank[0][0][0])
print("first_customer of first branch:",bank[1][0][0])
print("first_customer of first branch:",bank[2][0][0])
# Out:
# first_customer of first branch: Rahul
# first_customer of first branch: Arjun
# first_customer of first branch: Nikhil

# %%
print("second_customer of second branch:",bank[0][1][1][1])
print("second_customer of second branch:",bank[1][1][1][1])
print("second_customer of second branch:",bank[2][1][1][1])
# Out:
# second_customer of second branch: Vikram
# second_customer of second branch: Amit
# second_customer of second branch: Rohan

# %%
print("loan_amount last cust_bank3:",bank[1][1][2][3])
print("loan_amount last cust_bank 2:",bank[2][1][2][3])
# Out:
# loan_amount last cust_bank3: 650000
# loan_amount last cust_bank 2: 550000

# %% [markdown]
# 1. Create a list of 5 employee names and add a new employee using `append()`.

# %%
a=["Harish","Ramesh","suresh","naresh","girish"]
a.append("yash")
print(a)
# Out:
# ['Harish', 'Ramesh', 'suresh', 'naresh', 'girish', 'yash']

# %%
# 2. Create a list of account numbers and add three new account numbers using `extend()`.
a=[25,56,89.78,43]
a.extend([24,8,5])
print(a)
# Out:
# [25, 56, 89.78, 43, 24, 8, 5]

# %%
# Insert a new customer at the beginning of a customer list using `insert()`.
a=['d','b','c','d']
a.insert(0,'z')
print(a)
# Out:
# ['z', 'd', 'b', 'c', 'd']

# %%
#Insert a transaction amount at index 3 in a list.
a=[50,60,80,90]
a.insert(3,65)
print(a)
# Out:
# [50, 60, 80, 65, 90]

# %%
#Remove the last item from a list using `pop()`.
a=[6,9,7,3,2]
a.pop(-1)
print(a)
# Out:
# [6, 9, 7, 3]

# %%
 #Remove the customer "Rahul" from a customer list using `remove()`.
 a=["roshan","rohan","rocky","rahul","ramesh"]
 a.remove("rahul")
 print(a)
# Out:
# ['roshan', 'rohan', 'rocky', 'ramesh']

# %%
#Count how many times the account type "Savings" appears in a list using `count()`.
a=["savings","loan","savings","credit","savings"]
b=a.count("savings")
print(b)
# Out:
# 3

# %%
# Find the index of "Current" in a list of account types using `index()`.
a=["savings","loan","savings","credit","savings","current"]
b=a.index("current")
print(b)
# Out:
# 5

# %%
#9. Reverse a list of transaction IDs using `reverse()`.
a=[50,60,80,90,78,56,37]
a.reverse()
print(a)
# Out:
# [37, 56, 78, 90, 80, 60, 50]

# %%
#10. Sort a list of account balances in ascending order using `sort()`.
a=[50,60,80,90,78,56,37]
a.sort()
print(a)
# Out:
# [37, 50, 56, 60, 78, 80, 90]

# %%
#11. Sort a list of customer names in descending order using `sort()`.
a=[50,60,80,90,78,56,37,100,150]
a.sort(reverse=True)
print(a)
# Out:
# [150, 100, 90, 80, 78, 60, 56, 50, 37]

# %%
#12. Make a copy of a list using `copy()` and verify that modifying the copied list does not affect the original list.
a=[50,60,80,90,78,56,37,100,150]
b=a.copy()
b[2]=65
print(a)
print(b)
# Out:
# [50, 60, 80, 90, 78, 56, 37, 100, 150]
# [50, 60, 65, 90, 78, 56, 37, 100, 150]

# %%
#13. Clear all elements from a list using `clear()`.
a=[50,60,80,90,78,56,37,100,150]
a.clear()
print(a)
# Out:
# []

# %%
#14. Append a nested list containing a new customer's details to an existing customer list.
a=["c10","hari","loan",67]
a.append(["c11","krishna","savings",89])
print(a)
# Out:
# ['c10', 'hari', 'loan', 67, ['c11', 'krishna', 'savings', 89]]

# %%
#15. Extend a list of branch names with another list of new branches.
a=["ece","eee","civil"]
a.extend(["mech","cse","ai"])
print(a)
# Out:
# ['ece', 'eee', 'civil', 'mech', 'cse', 'ai']

# %%
#16. Remove the first occurrence of the balance `50000` from a list using `remove()`.
a=[50000,60000,50000,9000,19485]
a.remove(50000)
print(a)
# Out:
# [60000, 50000, 9000, 19485]

# %%
#17. Pop the element at index 2 from a list and print the removed value.
a=[50000,60000,70000,9000,19485]
b=a.pop(2)
print(a)
print(b)
# Out:
# [50000, 60000, 9000, 19485]
# 70000

# %%
#18. Count how many times the city "Bangalore" appears in a list
a=["hyderabad","bangalore","chennai","bangalore","madras","bangalore"]
b=a.count("bangalore")
print(b)
# Out:
# 3

# %%
#19. Reverse a list of bank names and print the result.

a=["sbi","union","hdfc","canara","axis"]
a.reverse()
print(a)
# Out:
# ['axis', 'canara', 'hdfc', 'union', 'sbi']

# %%
#20. Create a list of loan amounts and sort it in descending order.
a=[50000,60000,70000,9000,19485]
a.sort(reverse=True)
print(a)
# Out:
# [70000, 60000, 50000, 19485, 9000]

# %%
bank_branches = {"MG Road", "Indiranagar", "Whitefield", "Electronic City"}

customers = {"Rahul", "Anita", "Kiran", "Sneha", "Vikram"}

new_customers = {"Amit", "Priya", "Rahul", "Divya"}

loan_customers = {"Rahul", "Kiran", "Asha", "Ramesh"}

savings_customers = {"Rahul", "Sneha", "Priya", "Nikhil"}

transaction_ids = {101, 102, 103, 104, 105}

balances = {85000, 120000, 45000, 95000, 275000}

cities = {"Bangalore", "Hyderabad", "Chennai", "Pune"}

new_cities = {"Mumbai", "Bangalore", "Delhi"}

account_types = {"Savings", "Current", "Loan"}

# %%
print("customers",customers)
# Out:
# customers {'Rahul', 'Kiran', 'Anita', 'Vikram', 'Sneha'}

# %%
print("customers_ele:",len(customers))
# Out:
# customers_ele: 5

# %%
print("rahul exist in customer:",{"Rahul"}. issubset(customers))
print("Rahul" in customers)
# Out:
# rahul exist in customer: True
# True

# %%
print("Meena exist in customer:",{"Meena"}. issubset(customers))
print("Meena" in customers)
# Out:
# Meena exist in customer: False
# False

# %%
for i in bank_branches:
    print(i)
# Out:
# MG Road
# Indiranagar
# Whitefield
# Electronic City

# %%
#6. Add "Meena" to the `customers` set.
customers.add("meena")
print("customers:",customers)
# Out:
# customers: {'Rahul', 'Kiran', 'Anita', 'Vikram', 'meena', 'Sneha'}

# %%
#7. Add "Mysore" to the `cities` set.
cities.add("mysore")
print("cities: ",cities)
# Out:
# cities:  {'Pune', 'Bangalore', 'Chennai', 'mysore', 'Hyderabad'}

# %%
#8. Update the `customers` set with `new_customers`.
customers.update(new_customers)
print("customers:",customers)
# Out:
# customers: {'Rahul', 'Kiran', 'Anita', 'Divya', 'Vikram', 'Priya', 'meena', 'Amit', 'Sneha'}

# %%
#9. Update the `cities` set with `new_cities`.
cities.update(new_cities)
print("new_cities: ",cities)
# Out:
# new_cities:  {'Pune', 'Bangalore', 'Chennai', 'Delhi', 'mysore', 'Mumbai', 'Hyderabad'}

# %%
#10. Remove "Rahul" from the `customers` set.
customers.remove("Rahul")
print("customers:",customers)
# Out:
# customers: {'Kiran', 'Anita', 'Divya', 'Vikram', 'Priya', 'meena', 'Amit', 'Sneha'}

# %%
#11. Remove "Pune" from the `cities` set.
cities.remove("Pune")
print("cities:",cities)
# Out:
# cities: {'Bangalore', 'Chennai', 'Delhi', 'mysore', 'Mumbai', 'Hyderabad'}

# %%
#12. Discard "Anita" from the `customers` set.
customers.discard("Anita")
print("customers:",customers)
# Out:
# customers: {'Kiran', 'Divya', 'Vikram', 'Priya', 'meena', 'Amit', 'Sneha'}

# %%
#13. Discard "Delhi" from the `cities` set.
cities.discard("Delhi")
print("cities:",cities)
# Out:
# cities: {'Bangalore', 'Chennai', 'mysore', 'Mumbai', 'Hyderabad'}

# %%
#14. Discard "Kolkata" from the `cities` set.
cities.discard("kolkata")
print("cities:",cities)
# Out:
# cities: {'Bangalore', 'Chennai', 'mysore', 'Mumbai', 'Hyderabad'}

# %%
#15. Remove a random element from the `transaction_ids` set using `pop()`.
a=list(transaction_ids)
b=a.pop(2)
a=set(a)
print("transaction_ids:",a)
# Out:
# transaction_ids: {104, 105, 101, 102}

# %%
#16. Remove another random element from the `account_types` set.
a=list(account_types)
b=a.pop(1)
a=set(b)
print("account_types:",a)
# Out:
# account_types: {'r', 'C', 't', 'e', 'u', 'n'}

# %%
#17. Remove all elements from the `balances` set.
balances.clear()
print("balances:",balances)
# Out:
# balances: set()

# %%
#18. Create a copy of the `customers` set.
a=customers.copy()
print("customers:",a)
# Out:
# customers: {'Kiran', 'Divya', 'Vikram', 'Priya', 'meena', 'Amit', 'Sneha'}

# %%
#19. Modify the copied set and verify that the original set remains unchanged.
b=a.copy()
b.add("harish")
print("original:",a)
print("copied:",b)
# Out:
# original: {'Kiran', 'Divya', 'Vikram', 'Priya', 'meena', 'Amit', 'Sneha'}
# copied: {'Kiran', 'Divya', 'Vikram', 'Priya', 'harish', 'meena', 'Amit', 'Sneha'}

# %%
#20. Find the union of `customers` and `new_customers`.
x=customers.union(new_customers)
print(x)
# Out:
# {'Rahul', 'Kiran', 'Divya', 'Vikram', 'Priya', 'meena', 'Amit', 'Sneha'}

# %%
#21. Find the common customers between `customers` and `new_customers`.
customers.intersection(new_customers)
# Out:
# {'Amit', 'Divya', 'Priya'}

# %%
#22. Find customers who have both Savings and Loan accounts.
savings_customers.intersection(loan_customers)
# Out:
# {'Rahul'}

# %%
#23. Find customers present only in `customers` but not in `new_customers`.
c=customers.difference(new_customers)
print(customers)
print(new_customers)
print(c)
# Out:
# {'Kiran', 'Divya', 'Vikram', 'Priya', 'meena', 'Amit', 'Sneha'}
# {'Rahul', 'Amit', 'Divya', 'Priya'}
# {'Kiran', 'meena', 'Vikram', 'Sneha'}

# %%
#24. Find customers who have only Savings accounts.
savings_customers.difference(customers)
# Out:
# {'Nikhil', 'Rahul'}

# %%
#25. Find customers that are present in either `customers` or `new_customers` but not both.
customers.symmetric_difference(new_customers)
# Out:
# {'Kiran', 'Rahul', 'Sneha', 'Vikram', 'meena'}

# %%
{"Rahul","Anita"}.issubset(loan_customers)
# Out:
# False

# %%
#27. Check whether `customers` is a superset of `{"Rahul", "Anita"}`.
customers.issuperset({"Rahul","Anita"})
# Out:
# False

# %%
#28. Check whether `loan_customers` and `new_cities` are disjoint.
loan_customers.isdisjoint(new_cities)
# Out:
# True

# %%
#29. Find the maximum balance in the `balances` set.
max(balances)
# Out:
# 275000

# %%
#30. Find the minimum balance in the `balances` set.
min(balances)
# Out:
# 45000

# %%
#31. Find the total of all balances.
sum(balances)
# Out:
# 620000

# %%
#32. Sort the `balances` set in ascending order.
sorted(balances)
# Out:
# [45000, 85000, 95000, 120000, 275000]

# %%
#33. Convert the `customers` set into a list.
a=list(customers)
print(a)
# Out:
# ['Rahul', 'Kiran', 'Anita', 'Vikram', 'Sneha']

# %%
#34. Convert the `cities` set into a tuple.
a=tuple(cities)
print(a)
# Out:
# ('Bangalore', 'Hyderabad', 'Chennai', 'Pune')

# %%
#35. Remove duplicates from the list:
a=["Rahul", "Rahul", "Anita", "Sneha", "Sneha"]
set(a)
# Out:
# {'Anita', 'Rahul', 'Sneha'}

# %%
#36. Create an empty set.
k=set()
type(k)
# Out:
# set

# %%
#37. Add five employee names to the empty set.
k.add("hari")
k.add("giri")
k.add("siri")
k.add("nanda")
k.add("sai")
print(k)
# Out:
# {'hari', 'giri', 'sai', 'nanda', 'siri'}

# %%
#38. Find the length of the `account_types` set.
len(account_types)
# Out:
# 3

# %%
#39. Print every element of the `loan_customers` set using a loop.
for i in loan_customers:
    print(i)
# Out:
# Rahul
# Asha
# Kiran
# Ramesh

# %%
#40. Clear the `transaction_ids` set and verify that it is empty.
a=transaction_ids.clear()
print(transaction_ids)
print(a)
# Out:
# set()
# None
