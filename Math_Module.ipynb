# %% [markdown]
# <a href="https://colab.research.google.com/github/Harish-b19/python/blob/main/Math_Module.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

# %%
# 1.Write a program to calculate the square root of a number using the math module.

math.sqrt(25)
# Out:
# 5.0

# %%
# 2.Find the cube root of a given number using mathematical operations

math.pow(125,1/3)
# Out:
# 4.999999999999999

# %%
# 3.Calculate the factorial of a number using math.factorial()

math.factorial(5)
# Out:
# 120

# %%
# 4.Find the GCD (Greatest Common Divisor) of two numbers using
math.gcd(30,28)
# Out:
# 2

# %%
# 5.Find the LCM of two numbers using math.lcm().
math.lcm(28,35)
# Out:
# 140

# %%
# 6.Calculate the value of 5 raised to the power of 8 using math.pow().
math.pow(5,8)
# Out:
# 390625.0

# %%
# 7.Find the absolute value of a negative decimal number using math.fabs()
math.fabs(-128)
# Out:
# 128.0

# %%
# 8.Round a floating-point number up using math.ceil().
math.ceil(23.40)
# Out:
# 24

# %%
# 9.Round a floating-point number down using math.floor()
math.floor(23.90)
# Out:
# 23

# %%
# 10.Round a floating-point number to the nearest integer using round()
round(23.49)
# Out:
# 23

# %%
# 11.Find the remainder of two numbers using math.fmod()
math.fmod(28,25)
# Out:
# 3.0

# %%
# 12.Find the quotient and remainder using divmod().
divmod(625,8)
# Out:
# (78, 1)

# %%
# 13.Calculate the sine, cosine, and tangent of 45 degrees
print("sin 45: ",math.sin(45))
print("cos 45: ",math.cos(45))
print("tan 45: ",math.tan(45))
print("Total 45: ",math.sin(45)+math.cos(45)+math.tan(45))
# Out:
# sin 45:  0.8509035245341184
# cos 45:  0.5253219888177297
# tan 45:  1.6197751905438615
# Total 45:  2.9960007038957097

# %%
# 14.Convert an angle from degrees to radians.
r=40*(math.pi/180)
print(r)
# Out:
# 0.6981317007977318

# %%
# 15.Convert an angle from radians to degrees.
d=0.6981317007977318*(180/math.pi)
print(d)
# Out:
# 40.0

# %%
# 16.Find the logarithm (base 10) of a number using math.log10().
math.log10(10)
# Out:
# 1.0

# %%
# 17.Find the logarithm (base 10) of a number using math.log10().
x=int(input("enter the number: "))
math.log(x)
# Out:
# enter the number: 6
# 1.791759469228055

# %%
# 18.Calculate e raised to the power of x using math.exp().
math.exp(5)
# Out:
# 148.4131591025766

# %%
# 19.Find the value of π (pi) and Euler's number (e) from the math module
print(math.pi)
print(math.e)
# Out:
# 3.141592653589793
# 2.718281828459045

# %%
# 20.Find the distance between two points using math.dist().

math.dist((2,9),(4,5))
# Out:
# 4.47213595499958

# %%
# 21.Calculate the hypotenuse of a right triangle using math.hypot()

math.hypot(3,4)
# Out:
# 5.0

# %%
# 22.Find the combination (nCr) using math.comb().

math.comb(6,3)
# Out:
# 20

# %%
# 23.Find the permutation (nPr) using math.perm().
math.perm(6,3)
# Out:
# 120

# %%
# 24.Check whether a number is finite, infinite, or NaN using math.isfinite(), math.isinf(), and math.isnan()

n=float(input("enter the num"))

print(math.isfinite(n))
print(math.isinf(n))
print(math.isnan(n))
# Out:
# enter the numinf
# False
# True
# False

# %%
# 25.Find the product of all numbers in a list using math.prod().

math.prod([4,6,5,8,9.8675])
# Out:
# 9472.8

# %%
# 26.Find the sum of square roots of all numbers in a list.

n=[4,25,36,49,64]
t=(sum(math.sqrt(x) for x in n))
print(t)
# Out:
# 28.0

# %%
# 27.Find the largest integer less than or equal to the square root of a given number.

math.isqrt(36)
# Out:
# 6

# %%
#Calculate compound interest using math.pow()

p=int(input("enter the amount: "))
r=int(input("enter the percentage: "))
t=int(input("enter the time period: "))
x=p*math.pow((1+r/100),t)
print(x)
# Out:
# enter the amount: 15000
# enter the percentage: 5
# enter the time period: 3
# 17364.375000000004

# %%
# 29.Find the area and circumference of a circle using math.pi.
r=int(input("enter the radius: "))
print("area: ",math.pi*r**2)
print("circumference: ",2*math.pi*r)
# Out:
# enter the radius: 5
# area:  78.53981633974483
# circumference:  31.41592653589793

# %%
# 30.Create a scientific calculator that supports square root, factorial, logarithm, power, trigonometric functions, GCD, and LCM.

print("----scirntific calcualator----")
print("1.square root")
print("2.factorial")
print("3.logrithm")
print("4.pow")
print("5.sine")
print("6.cos")
print("7.tan")
print("8.gcd")
print("9.lcm")

n=int(input("enter the number: "))

if n==1:
  x=int(input("enter the number: "))
  print("sqrt: ",math.sqrt(x))

elif n==2:
  x=int(input("enter the number: "))
  print("fact: ",math.factorial(x))

elif n==3:
  x=int(input("enter the number: "))
  print("logrithm: ",math.log10(x))

elif n==4:
  b=int(input("enter the base: "))
  e=int(input("enter the exponent: "))
  print("power: ",math.pow(b,e))

elif n==5:
  x=int(input("enter the number: "))
  print("sin: ",math.sin(x))

elif n==6:
    x=int(input("enter the number: "))
    print("cos: ",math.cos(x))

elif n==7:
    x=int(input("enter the number: "))
    print("tan: ",math.tan(x))

elif n==8:
    x=int(input("enter the number: "))
    y=int(input("enter the number: "))
    print("gcd: ",math.gcd(x,y))

elif n==9:
    x=int(input("enter the number: "))
    y=int(input("enter the number: "))
    print("lcm: ",math.lcm(x,y))
else:
  print("invalid")
# Out:
# ----scirntific calcualator----
# 1.square root
# 2.factorial
# 3.logrithm
# 4.pow
# 5.sine
# 6.cos
# 7.tan
# 8.gcd
# 9.lcm
# enter the number: 9
# enter the number: 57
# enter the number: 89
# lcm:  5073
